# %%
import pandas as pd
import random as rd

# %%
filename = "C:/Users/Nishanth/depressiontraining.csv"

# %%
n = sum(1 for line in open(filename)) - 1

# %%
#to ignore the rows that are not multiples of 10000
skipidx = [x for x in range(1,n) if x%10000!=0]

# %%
#df = pd.read_csv(filename,header=0,skiprows=lambda i: i%1000!=0,encoding='latin-1')
#data = pd.read_csv(filename)
df = pd.read_csv(filename,skiprows=skipidx,encoding='latin-1')

# %%
df
# Out:
#      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_  \
# 0    0  1550731750  Sat Apr 18 07:05:35 PDT 2009  NO_QUERY  ARoadRetraveled
# 1    0  1556976546  Sun Apr 19 01:19:44 PDT 2009  NO_QUERY        Alicepire
# 2    0  1563649891  Sun Apr 19 23:40:15 PDT 2009  NO_QUERY        mattydoga
# 3    0  1573672565  Tue Apr 21 02:17:34 PDT 2009  NO_QUERY             GJRM
# 4    0  1678338169  Sat May 02 06:22:44 PDT 2009  NO_QUERY         alibelle
# 5    0  1686280091  Sun May 03 04:41:44 PDT 2009  NO_QUERY            furph
# 6    0  1693506527  Sun May 03 22:46:22 PDT 2009  NO_QUERY      luckygnahhh
# 7    0  1752114289  Sat May 09 21:05:02 PDT 2009  NO_QUERY     andywinter78
# 8    0  1755602056  Sun May 10 09:33:27 PDT 2009  NO_QUERY      sexlovelies
# 9    0  1793821193  Thu May 14 04:06:04 PDT 2009  NO_QUERY          vanjaaa
# 10   0  1824723089  Sun May 17 02:38:40 PDT 2009  NO_QUERY    TheAmazingCat
# ...
